# %% [markdown]
# # **Forest Fire Prediction**

# %% [markdown]
# ### Part 2: Data preparation
# In this section, we will focus on cleaning the raw data to ensure its quality and consistency. Data cleaning is an essential step in the data preprocessing pipeline, as it helps to eliminate errors, handle missing values, and transform the data into a suitable format for analysis.
#
# Data handling stages:
# - Handling Missing Values
# - Handling Duplicates
# - Data Conversion
# - Outliers and Validations

# %% [markdown]
# #### **Imports section:** (and warning exception handling)

# %%
# Please note if running on a clean environment, need to install missing modules
import pandas as pd
import numpy as np
import reverse_geocoder as rg
pd.options.mode.chained_assignment = None

# %% [markdown]
# #### Global variables:

# %%
# We are creating a new CSV file in each stage to minimize data loss if accrues 
CSV_NAME = 'fire_history.csv'
COLS_RED_CSV = 'fire_history_cols_reduction.csv'
MISS_CSV = 'fire_history_miss_values_removed.csv'
DUP_CSV = 'fire_history_dup_values_removed.csv'
DATA_CONV_CSV = 'fire_history_data_conv.csv'
ADD_COLS_CSV = 'fire_history_additional.csv'
CSV_OUTLIERS = 'fire_history_outliers_removed.csv'
#CSV_VALIDATION = 'fire_history_validation.csv'

FINAL_AFTER_PREP_CSV = 'fire_history_prep.csv'

COLS = ['UniqueFireIdentifier', 'FireDiscoveryDateTime', 'FireOutDateTime', 'InitialLatitude', 'InitialLongitude', 'POOCounty', 'FireCause']

# %% [markdown]
# #### Removing unnecessary columns:

# %%
def keep_necessary_columns(df, cols):
    df_cleaned = df[cols]
    return df_cleaned

# %% [markdown]
# #### Handling missing values:
# *The `handle_missing_values()` function is used to fill in missing values in the `FireCause` column before removing all rows with missing values.*

# %%
def handle_missing_values(df):
    df_cleaned = df.copy()
    df_cleaned['FireCause'].fillna('Undetermined', inplace=True)
    df_cleaned.dropna(inplace=True, ignore_index=True)
    return df_cleaned

# %% [markdown]
# #### Removing duplicates:
# *We are using `UniqueFireIdentifier` column to identify duplicates. Unique identifier assigned to each wildland fire.  yyyy = calendar year, SSUUUU = POO protecting unit identifier (5 or 6 characters), xxxxxx = local incident identifier (6 to 10 characters)*

# %%
def duplicated_values(df):
    df_cleaned = df.copy()
    df_cleaned.drop_duplicates(subset='UniqueFireIdentifier', keep='first', inplace=True)
    return df_cleaned

# %% [markdown]
# #### Data Type Conversion:
# *The `convert_date()` function converts dates into a useable format for our API and handles `pandas.to_datetime` limitations and human errors when entering data.*

# %%
def convert_date(dates):
    for i in range(len(dates)):
        try:
            dates[i] = pd.to_datetime(dates[i]).date()
        except:
            dates[i] = np.nan
    return dates

# %% [markdown]
# *The `data_conversion()` function converts our date columns to a usable format, and converts the `FireCause` column to a categorical column using `.map(cause_mapping)`.*

# %%
def data_conversion(df):
    df_cleaned = df.copy()

    # Convert FireDiscoveryDateTime and FireOutDateTime to useable format and remove missing values after conversion
    df_cleaned['FireDiscoveryDateTime'] = convert_date(df_cleaned['FireDiscoveryDateTime'])
    df_cleaned['FireOutDateTime'] = convert_date(df_cleaned['FireOutDateTime'])
    df_cleaned.dropna(inplace=True, ignore_index=True)

    # Convert FireCause to categorical column
    cause_mapping = {'Human': 1, 'Natural': 2, 'Unknown': 3, 'Undetermined': 4}
    df_cleaned['FireCause'] = df_cleaned['FireCause'].map(cause_mapping)

    return df_cleaned

# %% [markdown]
# #### Extras:
# *The `calc_days()` function calculates the difference in days between two dates.*

# %%
def calc_days(end_dates, start_dates):
    days = []
    for i in range(len(end_dates)):
        end_date = end_dates[i]
        start_date = start_dates[i]
        days.append((end_date - start_date).days)
    return days

# %% [markdown]
# *The `additional_cols()` functions adds two additional useful columns to the DataFrame.*

# %%
def additional_cols(df):
    df_extra = df.copy()

    # Add FireDuration column
    df_extra['FireDuration'] = calc_days(df_extra['FireOutDateTime'], df_extra['FireDiscoveryDateTime'])

    # Add CausedByWeather column
    df_extra['CausedByWeather'] = df_extra['FireCause'].apply(lambda x: 1 if x == 2 else 0)

    return (df_extra)

# %% [markdown]
# #### Validation and Detecting Outliers:
# *The `remove_outliers()` function is used to remove rows from a DataFrame based on a given boolean mask of outliers.*

# %%
def remove_outliers(df, outliers):
    for row in df.index:
        if outliers[row] == True:
            df.drop(row, inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# %% [markdown]
# *The `duration_outliers` function ensures there are no negative duration values, and the `calculate_outliers()` function calculates outliers based on the IQR range. The IQR is less sensitive to extreme values and can handle non-normal distributions.*

# %%
def duration_outliers(dur):
    outliers = []
    for d in dur:
        if d < 0:
            outliers.append(True)
        else:
            outliers.append(False)
    return outliers

# %%
def calculate_outliers(data):
    outliers = []
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)
    for x in data:
        if x < lower_bound or x > upper_bound:
            outliers.append(True)
        else:
            outliers.append(False)
    return outliers

# %% [markdown]
# *The `coordinates_outliers()` and `valid_locations()` functions ensure that the coordinates are in range and valid.*

# %%
def coordinates_outliers(lats, longs):
    outliers = []
    for i in range(len(lats)):
        lat = lats[i]
        long = longs[i]
        if lat == 0 or long == 0:
            outliers.append(True)
        elif lat < -90 or lat > 90 or long < -180 or long > 180:
            outliers.append(True)
        else:
            outliers.append(False)
    return outliers

# %%
def valid_locations(valid_results, counties):
    for i in range(len(valid_results)):
        county = counties[i].lower()
        valid_county = valid_results[i]['admin2']
        valid_country = valid_results[i]['cc']

        if valid_county is None or county not in valid_county.lower() or valid_country != 'US':
            counties[i] = np.nan
            
    return counties

# %% [markdown]
# *And FINALLY - The `handle_outliers()` and `validate_data()` functions that are responsible for handling outliers and validating data in the given DataFrame.*

# %%
def handle_outliers(df):
    df_cleaned = df.copy()

    # Analyze fire duration values
    fire_duration_outliers = duration_outliers(df_cleaned['FireDuration'])
    df_cleaned = remove_outliers(df_cleaned, fire_duration_outliers)
    fire_duration_IQR_outliers = calculate_outliers(df_cleaned['FireDuration'])  
    df_cleaned = remove_outliers(df_cleaned, fire_duration_IQR_outliers)

    # Analyze coordinates values
    fire_coordinates_outliers = coordinates_outliers(df_cleaned['InitialLatitude'], df_cleaned['InitialLongitude'])
    df_cleaned = remove_outliers(df_cleaned, fire_coordinates_outliers)

    return df_cleaned

# %%
def validate_data(df):
    valid_df = df.copy()

    lats = valid_df['InitialLatitude'].to_list()
    longs = valid_df['InitialLongitude'].to_list()
    coords = list(zip(lats, longs))

    # Analyze location values
    results = rg.search(coords)
    valid_df['POOCounty'] = valid_locations(results, valid_df['POOCounty'])
    valid_df.dropna(inplace=True, ignore_index=True)

    return valid_df

# %% [markdown]
# ### Implementation section:
# Out data before any handling and preparations

# %%
df = pd.read_csv(CSV_NAME)
df
# Out:
# C:\Users\jenza\AppData\Local\Temp\ipykernel_32220\799376281.py:1: DtypeWarning: Columns (6,7,15,16,34,63,66,70,71,79,87,88,92,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(CSV_NAME)
#                  X          Y  OBJECTID  SourceOID ABCDMisc  \
# 0      -118.180712  33.808985         1    7747595      NaN
# 1      -117.153901  33.176394         2    6384391      NaN
# 2      -121.104180  38.834727         3    1383752      NaN
# 3      -117.228592  33.782442         4   22499589      NaN
# 4      -118.309032  33.941815         5   23869477      NaN
# ...            ...        ...       ...        ...      ...
# 263817 -116.073913  43.243246    315324   28035649      NaN
# 263818 -116.026013  43.184536    315326   28035650      NaN
# 263819 -116.069113  43.241006    315327   28035652      NaN
# 263820 -151.187739  60.447151    315328   28035653      NaN
# 263821 -116.021813  43.189436    315329   28035654      NaN
#
#        ADSPermissionState     ContainmentDateTime         ControlDateTime  \
# 0                 DEFAULT                     NaN                     NaN
# 1                 DEFAULT                     NaN                     NaN
# 2                 DEFAULT                     NaN                     NaN
# 3                 DEFAULT                     NaN                     NaN
# 4                 DEFAULT                     NaN                     NaN
# ...                   ...                     ...                     ...
# 263817      FIREREPORTING  2023/05/20 19:06:00+00  2023/05/20 19:06:00+00
# 263818      FIREREPORTING  2023/05/20 19:33:00+00  2023/05/20 19:33:00+00
# 263819      FIREREPORTING  2023/05/20 23:30:00+00  2023/05/20 23:30:00+00
# 263820            DEFAULT  2023/06/19 08:19:42+00  2023/06/19 08:37:23+00
# 263821      FIREREPORTING  2023/05/20 22:29:00+00  2023/05/20 22:29:00+00
#
#        CreatedBySystem  IncidentSize  ...  EstimatedFinalCost  \
# 0              lacocad           NaN  ...                 NaN
# 1             firecode           NaN  ...                 NaN
# 2             firecode           NaN  ...                 NaN
# 3                cfcad           NaN  ...                 NaN
# 4              lacocad           NaN  ...                 NaN
# ...                ...           ...  ...                 ...
# 263817         wildcad          0.50  ...                 NaN
# 263818         wildcad          0.50  ...                 NaN
# 263819         wildcad         20.00  ...                 NaN
# 263820             ifm          0.10  ...                 NaN
# 263821         wildcad          0.25  ...                 NaN
#
#        OrganizationalAssessment  StrategicDecisionPublishDate  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# ...                         ...                           ...
# 263817                      NaN                           NaN
# 263818                      NaN                           NaN
# 263819                      NaN                           NaN
# 263820                      NaN                           NaN
# 263821                      NaN                           NaN
#
#               CreatedOnDateTime_dt       ModifiedOnDateTime_dt IsCpxChild  \
# 0       2020/02/28 20:52:36.363+00  2020/02/28 20:52:36.363+00          0
# 1       2019/07/01 20:10:12.737+00  2019/07/01 20:10:12.737+00          0
# 2       2016/06/20 22:39:02.410+00  2016/06/20 22:39:02.410+00          0
# 3       2021/11/25 15:24:53.120+00  2021/11/25 15:24:53.120+00          0
# 4       2022/11/21 11:28:49.097+00  2022/11/21 11:28:49.097+00          0
# ...                            ...                         ...        ...
# 263817  2023/06/19 16:23:18.380+00  2023/06/19 16:26:42.300+00          0
# 263818  2023/06/19 16:28:15.883+00  2023/06/19 16:28:37.680+00          0
# 263819  2023/06/19 16:35:53.457+00  2023/06/19 16:36:22.327+00          0
# 263820  2023/06/19 16:40:37.620+00  2023/06/19 16:44:40.917+00          0
# 263821  2023/06/19 16:42:50.950+00  2023/06/19 16:43:27.187+00          0
#
#        CpxName CpxID                          SourceGlobalID  \
# 0          NaN   NaN  {6A311ABB-DF4F-4947-B8DD-3900BDA784F6}
# 1          NaN   NaN  {1AF2C949-B159-4D8F-8D39-90CB58BC5DD5}
# 2          NaN   NaN  {1B179EA1-97CE-4699-915B-374754BCBC5B}
# 3          NaN   NaN  {E61E387B-4ED7-4971-9604-C5D7391FAF77}
# 4          NaN   NaN  {AEB6F7A3-A109-4132-9FEB-FB1EE1DF3193}
# ...        ...   ...                                     ...
# 263817     NaN   NaN  {1553284C-4F2F-4D1E-8DFF-77F4593289FE}
# 263818     NaN   NaN  {2957B1E7-485A-4BE8-8914-2EEAD0823DF3}
# 263819     NaN   NaN  {B0A31C1B-638A-4FBC-AF6F-E8BAC9DFCED5}
# 263820     NaN   NaN  {F8490B1B-82F1-4851-8386-F121978FE268}
# 263821     NaN   NaN  {C3E400BD-7C1C-46FF-966D-B0922F409409}
#
#                                     GlobalID
# 0       48d2c0e2-5e38-4d40-9d5e-066b076c7d98
# 1       17d2d66a-d451-4592-a172-7b2c860a2cc9
# 2       60c471ff-3c85-41b4-9135-e7338d7ec90b
# 3       149237ec-a42e-43d6-9318-22207a705dd9
# 4       ef7675e3-d5be-412a-a6c1-0d63fc7153c8
# ...                                      ...
# 263817  32553b11-17d3-405a-82ff-1cfbdfa6492e
# 263818  09c8f1ca-6e1f-4438-b929-55488216cb74
# 263819  72a22987-ba12-414c-9b8e-63eaa2587dd9
# 263820  197b872b-1932-46aa-a7e6-628097227187
# 263821  5577e6c0-aca5-4d05-bee3-1873a8d19df3
#
# [263822 rows x 96 columns]

# %%
df = keep_necessary_columns(df, COLS)
df.to_csv(COLS_RED_CSV, index=False)
df
# Out:
#        UniqueFireIdentifier   FireDiscoveryDateTime         FireOutDateTime  \
# 0         2020-CALAC-066100  2020/02/28 20:45:40+00                     NaN
# 1         2019-CAMVU-009269  2019/07/01 19:54:00+00                     NaN
# 2         2016-CANEU-014375  2016/06/20 22:06:00+00                     NaN
# 3         2021-CARRU-163915  2021/11/25 15:17:33+00                     NaN
# 4         2022-CALAC-396331  2022/11/21 11:25:34+00                     NaN
# ...                     ...                     ...                     ...
# 263817   2023-IDIDNG-000356  2023/05/20 18:30:00+00  2023/05/20 19:06:00+00
# 263818   2023-IDIDNG-000357  2023/05/20 19:15:00+00  2023/05/20 19:33:00+00
# 263819   2023-IDIDNG-000358  2023/05/20 20:28:00+00  2023/05/20 23:30:00+00
# 263820    2023-AKKKS-303132  2023/06/19 05:14:10+00                     NaN
# 263821   2023-IDIDNG-000359  2023/05/20 21:55:00+00  2023/05/20 22:29:00+00
#
#         InitialLatitude  InitialLongitude        POOCounty     FireCause
# 0             33.808980       -118.180700      Los Angeles       Unknown
# 1                   NaN               NaN        San Diego           NaN
# 2                   NaN               NaN           Placer           NaN
# 3             33.782437       -117.228580        Riverside  Undetermined
# 4             33.941810       -118.309020      Los Angeles  Undetermined
# ...                 ...               ...              ...           ...
# 263817        43.243240       -116.073900              Ada         Human
# 263818        43.184530       -116.026000              Ada         Human
# 263819        43.241000       -116.069100              Ada         Human
# 263820        60.447150       -151.187717  Kenai Peninsula         Human
# 263821        43.189430       -116.021800              Ada         Human
#
# [263822 rows x 7 columns]

# %%
df = handle_missing_values(df)
df.to_csv(MISS_CSV, index=False)
df
# Out:
#        UniqueFireIdentifier   FireDiscoveryDateTime         FireOutDateTime  \
# 0         2022-MTCRA-220737  2022/09/19 06:08:00+00  2022/11/07 18:05:00+00
# 1         2022-COUMA-000926  2022/08/09 21:32:00+00  2022/08/15 20:39:00+00
# 2         2022-LASBR-000250  2022/12/10 01:09:19+00  2022/12/11 19:30:00+00
# 3         2022-WAMSF-000348  2022/09/02 20:08:00+00  2022/12/16 21:13:00+00
# 4         2022-WACOF-001050  2022/04/14 17:30:00+00  2023/01/12 16:30:00+00
# ...                     ...                     ...                     ...
# 126749   2023-IDIDNG-000355  2023/05/19 00:08:00+00  2023/05/19 00:16:00+00
# 126750   2023-IDIDNG-000356  2023/05/20 18:30:00+00  2023/05/20 19:06:00+00
# 126751   2023-IDIDNG-000357  2023/05/20 19:15:00+00  2023/05/20 19:33:00+00
# 126752   2023-IDIDNG-000358  2023/05/20 20:28:00+00  2023/05/20 23:30:00+00
# 126753   2023-IDIDNG-000359  2023/05/20 21:55:00+00  2023/05/20 22:29:00+00
#
#         InitialLatitude  InitialLongitude  POOCounty     FireCause
# 0              45.62299        -107.46470   Big Horn  Undetermined
# 1              37.17861        -108.88910  Montezuma       Natural
# 2              29.86160         -93.77264    Cameron  Undetermined
# 3              47.63933        -121.60540       King  Undetermined
# 4              48.55950        -119.06330   Okanogan  Undetermined
# ...                 ...               ...        ...           ...
# 126749         43.19766        -116.03630        Ada         Human
# 126750         43.24324        -116.07390        Ada         Human
# 126751         43.18453        -116.02600        Ada         Human
# 126752         43.24100        -116.06910        Ada         Human
# 126753         43.18943        -116.02180        Ada         Human
#
# [126754 rows x 7 columns]

# %%
df = duplicated_values(df)
df.to_csv(DUP_CSV, index=False)
df
# Out:
#        UniqueFireIdentifier   FireDiscoveryDateTime         FireOutDateTime  \
# 0         2022-MTCRA-220737  2022/09/19 06:08:00+00  2022/11/07 18:05:00+00
# 1         2022-COUMA-000926  2022/08/09 21:32:00+00  2022/08/15 20:39:00+00
# 2         2022-LASBR-000250  2022/12/10 01:09:19+00  2022/12/11 19:30:00+00
# 3         2022-WAMSF-000348  2022/09/02 20:08:00+00  2022/12/16 21:13:00+00
# 4         2022-WACOF-001050  2022/04/14 17:30:00+00  2023/01/12 16:30:00+00
# ...                     ...                     ...                     ...
# 126749   2023-IDIDNG-000355  2023/05/19 00:08:00+00  2023/05/19 00:16:00+00
# 126750   2023-IDIDNG-000356  2023/05/20 18:30:00+00  2023/05/20 19:06:00+00
# 126751   2023-IDIDNG-000357  2023/05/20 19:15:00+00  2023/05/20 19:33:00+00
# 126752   2023-IDIDNG-000358  2023/05/20 20:28:00+00  2023/05/20 23:30:00+00
# 126753   2023-IDIDNG-000359  2023/05/20 21:55:00+00  2023/05/20 22:29:00+00
#
#         InitialLatitude  InitialLongitude  POOCounty     FireCause
# 0              45.62299        -107.46470   Big Horn  Undetermined
# 1              37.17861        -108.88910  Montezuma       Natural
# 2              29.86160         -93.77264    Cameron  Undetermined
# 3              47.63933        -121.60540       King  Undetermined
# 4              48.55950        -119.06330   Okanogan  Undetermined
# ...                 ...               ...        ...           ...
# 126749         43.19766        -116.03630        Ada         Human
# 126750         43.24324        -116.07390        Ada         Human
# 126751         43.18453        -116.02600        Ada         Human
# 126752         43.24100        -116.06910        Ada         Human
# 126753         43.18943        -116.02180        Ada         Human
#
# [126742 rows x 7 columns]

# %%
df = data_conversion(df)
df.to_csv(DATA_CONV_CSV, index=False)
df
# Out:
#        UniqueFireIdentifier FireDiscoveryDateTime FireOutDateTime  \
# 0         2022-MTCRA-220737            2022-09-19      2022-11-07
# 1         2022-COUMA-000926            2022-08-09      2022-08-15
# 2         2022-LASBR-000250            2022-12-10      2022-12-11
# 3         2022-WAMSF-000348            2022-09-02      2022-12-16
# 4         2022-WACOF-001050            2022-04-14      2023-01-12
# ...                     ...                   ...             ...
# 126736   2023-IDIDNG-000355            2023-05-19      2023-05-19
# 126737   2023-IDIDNG-000356            2023-05-20      2023-05-20
# 126738   2023-IDIDNG-000357            2023-05-20      2023-05-20
# 126739   2023-IDIDNG-000358            2023-05-20      2023-05-20
# 126740   2023-IDIDNG-000359            2023-05-20      2023-05-20
#
#         InitialLatitude  InitialLongitude  POOCounty  FireCause
# 0              45.62299        -107.46470   Big Horn          4
# 1              37.17861        -108.88910  Montezuma          2
# 2              29.86160         -93.77264    Cameron          4
# 3              47.63933        -121.60540       King          4
# 4              48.55950        -119.06330   Okanogan          4
# ...                 ...               ...        ...        ...
# 126736         43.19766        -116.03630        Ada          1
# 126737         43.24324        -116.07390        Ada          1
# 126738         43.18453        -116.02600        Ada          1
# 126739         43.24100        -116.06910        Ada          1
# 126740         43.18943        -116.02180        Ada          1
#
# [126741 rows x 7 columns]

# %%
df = additional_cols(df)
df.to_csv(ADD_COLS_CSV, index=False)
df
# Out:
#        UniqueFireIdentifier FireDiscoveryDateTime FireOutDateTime  \
# 0         2022-MTCRA-220737            2022-09-19      2022-11-07
# 1         2022-COUMA-000926            2022-08-09      2022-08-15
# 2         2022-LASBR-000250            2022-12-10      2022-12-11
# 3         2022-WAMSF-000348            2022-09-02      2022-12-16
# 4         2022-WACOF-001050            2022-04-14      2023-01-12
# ...                     ...                   ...             ...
# 126736   2023-IDIDNG-000355            2023-05-19      2023-05-19
# 126737   2023-IDIDNG-000356            2023-05-20      2023-05-20
# 126738   2023-IDIDNG-000357            2023-05-20      2023-05-20
# 126739   2023-IDIDNG-000358            2023-05-20      2023-05-20
# 126740   2023-IDIDNG-000359            2023-05-20      2023-05-20
#
#         InitialLatitude  InitialLongitude  POOCounty  FireCause  FireDuration  \
# 0              45.62299        -107.46470   Big Horn          4            49
# 1              37.17861        -108.88910  Montezuma          2             6
# 2              29.86160         -93.77264    Cameron          4             1
# 3              47.63933        -121.60540       King          4           105
# 4              48.55950        -119.06330   Okanogan          4           273
# ...                 ...               ...        ...        ...           ...
# 126736         43.19766        -116.03630        Ada          1             0
# 126737         43.24324        -116.07390        Ada          1             0
# 126738         43.18453        -116.02600        Ada          1             0
# 126739         43.24100        -116.06910        Ada          1             0
# 126740         43.18943        -116.02180        Ada          1             0
#
#         CausedByWeather
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 126736                0
# 126737                0
# 126738                0
# 126739                0
# 126740                0
#
# [126741 rows x 9 columns]

# %%
df = handle_outliers(df)
df.to_csv(CSV_OUTLIERS, index=False)
df
# Out:
#        UniqueFireIdentifier FireDiscoveryDateTime FireOutDateTime  \
# 0         2022-COUMA-000926            2022-08-09      2022-08-15
# 1         2022-LASBR-000250            2022-12-10      2022-12-11
# 2         2022-AZGID-000143            2022-03-14      2022-03-15
# 3         2022-PAPAS-001588            2022-11-09      2022-11-10
# 4         2022-AZFTA-000943            2022-10-29      2022-11-01
# ...                     ...                   ...             ...
# 112497   2023-IDIDNG-000355            2023-05-19      2023-05-19
# 112498   2023-IDIDNG-000356            2023-05-20      2023-05-20
# 112499   2023-IDIDNG-000357            2023-05-20      2023-05-20
# 112500   2023-IDIDNG-000358            2023-05-20      2023-05-20
# 112501   2023-IDIDNG-000359            2023-05-20      2023-05-20
#
#         InitialLatitude  InitialLongitude  POOCounty  FireCause  FireDuration  \
# 0              37.17861        -108.88910  Montezuma          2             6
# 1              29.86160         -93.77264    Cameron          4             1
# 2              33.11710        -110.77040       Gila          1             1
# 3              41.70000         -79.03100     Warren          1             1
# 4              33.99352        -110.48160       Gila          4             3
# ...                 ...               ...        ...        ...           ...
# 112497         43.19766        -116.03630        Ada          1             0
# 112498         43.24324        -116.07390        Ada          1             0
# 112499         43.18453        -116.02600        Ada          1             0
# 112500         43.24100        -116.06910        Ada          1             0
# 112501         43.18943        -116.02180        Ada          1             0
#
#         CausedByWeather
# 0                     1
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 112497                0
# 112498                0
# 112499                0
# 112500                0
# 112501                0
#
# [112502 rows x 9 columns]

# %%
df = validate_data(df)
df.to_csv(FINAL_AFTER_PREP_CSV, index=False)
df
# Out:
#       UniqueFireIdentifier FireDiscoveryDateTime FireOutDateTime  \
# 0        2022-COUMA-000926            2022-08-09      2022-08-15
# 1        2022-PAPAS-001588            2022-11-09      2022-11-10
# 2        2022-ORNOD-220301            2022-08-17      2022-08-17
# 3        2022-ORNOD-220285            2022-08-13      2022-08-14
# 4       2022-ORBENN-000436            2022-07-26      2022-07-26
# ...                    ...                   ...             ...
# 83421    2023-IDBOD-000349            2023-06-18      2023-06-20
# 83422    2023-CASNF-000573            2023-06-18      2023-06-19
# 83423    2023-AZA5S-230819            2023-06-18      2023-06-19
# 83424    2023-AZA3S-230824            2023-06-19      2023-06-19
# 83425   2023-MTLG13-023112            2023-06-12      2023-06-17
#
#        InitialLatitude  InitialLongitude  POOCounty  FireCause  FireDuration  \
# 0            37.178610       -108.889100  Montezuma          2             6
# 1            41.700000        -79.031000     Warren          1             1
# 2            43.831530       -122.733900       Lane          1             0
# 3            43.837670       -122.773600       Lane          1             1
# 4            44.007700       -121.223700  Deschutes          1             0
# ...                ...               ...        ...        ...           ...
# 83421        43.330760       -116.409500        Ada          1             2
# 83422        37.568056       -119.843889   Mariposa          4             1
# 83423        35.892840       -114.087600     Mohave          1             1
# 83424        32.645000       -111.392900      Pinal          1             0
# 83425        46.223000       -114.117000    Ravalli          4             5
#
#        CausedByWeather
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 83421                0
# 83422                0
# 83423                0
# 83424                0
# 83425                0
#
# [83426 rows x 9 columns]

# %%
print("DataFrame information:")
df.info()
print()
print("DataFrame description:")
df.describe(include='all')
# Out:
# DataFrame information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83426 entries, 0 to 83425
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   UniqueFireIdentifier   83426 non-null  object
#  1   FireDiscoveryDateTime  83426 non-null  object
#  2   FireOutDateTime        83426 non-null  object
#  3   InitialLatitude        83426 non-null  float64
#  4   InitialLongitude       83426 non-null  float64
#  5   POOCounty              83426 non-null  object
#  6   FireCause              83426 non-null  int64
#  7   FireDuration           83426 non-null  int64
#  8   CausedByWeather        83426 non-null  int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 5.7+ MB
#
# DataFrame description:
#        UniqueFireIdentifier FireDiscoveryDateTime FireOutDateTime  \
# count                 83426                 83426           83426
# unique                83426                  3189            3194
# top       2022-COUMA-000926            2020-07-05      2021-07-05
# freq                      1                   258             163
# mean                    NaN                   NaN             NaN
# std                     NaN                   NaN             NaN
# min                     NaN                   NaN             NaN
# 25%                     NaN                   NaN             NaN
# 50%                     NaN                   NaN             NaN
# 75%                     NaN                   NaN             NaN
# max                     NaN                   NaN             NaN
#
#         InitialLatitude  InitialLongitude POOCounty     FireCause  \
# count      83426.000000      83426.000000     83426  83426.000000
# unique              NaN               NaN       976           NaN
# top                 NaN               NaN  Coconino           NaN
# freq                NaN               NaN      1848           NaN
# mean          40.557980       -109.908788       NaN      1.727315
# std            6.594656         12.933619       NaN      0.994427
# min           25.136111       -167.075908       NaN      1.000000
# 25%           35.203945       -116.987375       NaN      1.000000
# 50%           40.108000       -111.582950       NaN      1.000000
# 75%           45.099650       -105.086100       NaN      2.000000
# max           70.135860        -67.042280       NaN      4.000000
#
#         FireDuration  CausedByWeather
# count   83426.000000     83426.000000
# unique           NaN              NaN
# top              NaN              NaN
# freq             NaN              NaN
# mean        4.892791         0.268501
# std         5.755790         0.443183
# min         0.000000         0.000000
# 25%         1.000000         0.000000
# 50%         3.000000         0.000000
# 75%         7.000000         1.000000
# max        26.000000         1.000000
